# %%
# ---------------------------------------------------------
# EXPERIMENT 5 - Continuous Bag of Words (CBOW) with Keras
# ---------------------------------------------------------

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Lambda, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
import re, os
from gensim.models import KeyedVectors

# %%
# Reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Step 2: Small dataset (you can replace with your own sentences)

paragraph = (
    "It is a pleasant day. I love to walk in the park. "
    "The birds are singing and the breeze is cool. "
    "Children are playing games with joy. "
    "Learning new things every day feels rewarding."
)

print(paragraph)
# Out:
# It is a pleasant day. I love to walk in the park. The birds are singing and the breeze is cool. Children are playing games with joy. Learning new things every day feels rewarding.

# %%
# Step 3: Preprocess and tokenize

def simple_clean(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z0-9\s\.]", "", text)  # keep letters, numbers, space, dot
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Clean text
cleaned = simple_clean(paragraph)

# Split into sentences
sentences = [s.strip() for s in cleaned.split('.') if s.strip()]
print("Sentences:", sentences)

# Tokenize
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)

word_index = tokenizer.word_index
vocab_size = len(word_index) + 1  # +1 for padding
print("Vocabulary size:", vocab_size)
print("Word index:", word_index)

# Convert sentences to sequences of word IDs
seqs = tokenizer.texts_to_sequences(sentences)
print("Sequences:", seqs)
# Out:
# Sentences: ['it is a pleasant day', 'i love to walk in the park', 'the birds are singing and the breeze is cool', 'children are playing games with joy', 'learning new things every day feels rewarding']
# Vocabulary size: 31
# Word index: {'<OOV>': 1, 'the': 2, 'is': 3, 'day': 4, 'are': 5, 'it': 6, 'a': 7, 'pleasant': 8, 'i': 9, 'love': 10, 'to': 11, 'walk': 12, 'in': 13, 'park': 14, 'birds': 15, 'singing': 16, 'and': 17, 'breeze': 18, 'cool': 19, 'children': 20, 'playing': 21, 'games': 22, 'with': 23, 'joy': 24, 'learning': 25, 'new': 26, 'things': 27, 'every': 28, 'feels': 29, 'rewarding': 30}
# Sequences: [[6, 3, 7, 8, 4], [9, 10, 11, 12, 13, 2, 14], [2, 15, 5, 16, 17, 2, 18, 3, 19], [20, 5, 21, 22, 23, 24], [25, 26, 27, 28, 4, 29, 30]]

# %%
def cbow_training_pairs(seqs, window_size, vocab_size):
    contexts = []
    targets = []
    total_len = 2 * window_size  # left + right context
    
    for text in seqs:
        L = len(text)
        for idx, word in enumerate(text):
            if word == 0:
                continue
            
            start = max(0, idx - window_size)
            end = min(L, idx + window_size + 1)
            
            # Collect context words (exclude target word)
            context = [text[i] for i in range(start, end) if i != idx]
            
            # Pad context
            if len(context) < total_len:
                pad_left = (total_len - len(context)) // 2
                pad_right = total_len - len(context) - pad_left
                context = [0] * pad_left + context + [0] * pad_right
            else:
                context = context[:total_len]
            
            contexts.append(context)
            targets.append(word)
    
    X = np.array(contexts)
    y = to_categorical(np.array(targets), num_classes=vocab_size)
    return X, y

# %%
# Step 5: Build CBOW model

embed_dim = 50
window_size = 2
context_len = 2 * window_size

model = Sequential([
    Input(shape=(context_len,)),
    Embedding(input_dim=vocab_size, output_dim=embed_dim, name="embedding"),
    Lambda(lambda x: tf.reduce_mean(x, axis=1), name="context_mean"),
    Dense(vocab_size, activation="softmax")
])

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# WARNING:tensorflow:From D:\Anaconda\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 4, 50)               │           1,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ context_mean (Lambda)                │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 31)                  │           1,581 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,131 (12.23 KB)
#  Trainable params: 3,131 (12.23 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
window_size = 2
X, y = cbow_training_pairs(seqs, window_size, vocab_size)
print("X shape:", X.shape, "y shape:", y.shape)
# Out:
# X shape: (34, 4) y shape: (34, 31)

# %%
history = model.fit(X, y, epochs=200, batch_size=32, verbose=1)
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.0294 - loss: 3.4360
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0588 - loss: 3.4299
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0882 - loss: 3.4252
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.1176 - loss: 3.4206
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2059 - loss: 3.4161
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2353 - loss: 3.4116
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2647 - loss: 3.4071
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2941 - loss: 3.4026
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2647 - loss: 3.3981
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2647 - loss: 3.3935
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2941 - loss: 3.3890
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3529 - loss: 3.3843
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3235 - loss: 3.3797
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2941 - loss: 3.3749
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2941 - loss: 3.3701
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2941 - loss: 3.3653
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.2941 - loss: 3.3603
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2941 - loss: 3.3553
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2941 - loss: 3.3502
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2941 - loss: 3.3450
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2941 - loss: 3.3397
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2941 - loss: 3.3343
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2941 - loss: 3.3288
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2941 - loss: 3.3232
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2941 - loss: 3.3175
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2941 - loss: 3.3117
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.2941 - loss: 3.3058
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3235 - loss: 3.2997
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3235 - loss: 3.2936
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3235 - loss: 3.2873
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3235 - loss: 3.2809
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3235 - loss: 3.2743
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3235 - loss: 3.2677
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3235 - loss: 3.2609
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3235 - loss: 3.2540
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3235 - loss: 3.2470
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3235 - loss: 3.2398
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3235 - loss: 3.2325
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3235 - loss: 3.2251
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3235 - loss: 3.2175
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3235 - loss: 3.2098
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3235 - loss: 3.2020
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3235 - loss: 3.1941
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3235 - loss: 3.1860
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3235 - loss: 3.1778
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3529 - loss: 3.1695
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3529 - loss: 3.1611
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3529 - loss: 3.1525
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3529 - loss: 3.1438
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3529 - loss: 3.1350
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3529 - loss: 3.1261
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3529 - loss: 3.1171
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3529 - loss: 3.1079
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3529 - loss: 3.0987
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3529 - loss: 3.0893
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3529 - loss: 3.0798
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3529 - loss: 3.0703
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3529 - loss: 3.0606
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3529 - loss: 3.0508
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3824 - loss: 3.0409
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3824 - loss: 3.0310
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3824 - loss: 3.0209
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3824 - loss: 3.0108
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3824 - loss: 3.0006
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3824 - loss: 2.9903
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3824 - loss: 2.9799
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3824 - loss: 2.9694
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4118 - loss: 2.9589
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4118 - loss: 2.9483
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4118 - loss: 2.9377
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4118 - loss: 2.9270
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4118 - loss: 2.9162
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4118 - loss: 2.9054
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4118 - loss: 2.8946
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4118 - loss: 2.8836
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4118 - loss: 2.8727
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4118 - loss: 2.8617
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4118 - loss: 2.8506
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4118 - loss: 2.8395
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4118 - loss: 2.8284
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4118 - loss: 2.8172
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4412 - loss: 2.8060
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4412 - loss: 2.7947
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4412 - loss: 2.7834
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4412 - loss: 2.7721
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4412 - loss: 2.7607
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4412 - loss: 2.7493
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4412 - loss: 2.7379
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4412 - loss: 2.7264
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4412 - loss: 2.7149
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4412 - loss: 2.7033
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4412 - loss: 2.6917
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4412 - loss: 2.6800
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4412 - loss: 2.6683
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4412 - loss: 2.6565
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4412 - loss: 2.6447
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4412 - loss: 2.6328
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4412 - loss: 2.6209
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4412 - loss: 2.6089
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4412 - loss: 2.5969
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4412 - loss: 2.5848
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4412 - loss: 2.5726
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4412 - loss: 2.5604
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4412 - loss: 2.5481
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4412 - loss: 2.5358
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4412 - loss: 2.5233
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4412 - loss: 2.5109
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4412 - loss: 2.4983
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4412 - loss: 2.4857
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4412 - loss: 2.4730
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4412 - loss: 2.4603
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4412 - loss: 2.4475
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4412 - loss: 2.4346
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4412 - loss: 2.4217
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4412 - loss: 2.4087
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4412 - loss: 2.3957
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4412 - loss: 2.3826
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4412 - loss: 2.3695
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4412 - loss: 2.3563
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4706 - loss: 2.3430
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4706 - loss: 2.3298
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4706 - loss: 2.3164
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4706 - loss: 2.3031
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4706 - loss: 2.2897
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4706 - loss: 2.2762
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4706 - loss: 2.2628
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4706 - loss: 2.2493
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4706 - loss: 2.2358
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4706 - loss: 2.2223
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5000 - loss: 2.2087
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5000 - loss: 2.1952
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 2.1816
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 2.1680
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 2.1545
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 2.1409
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5000 - loss: 2.1273
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 2.1138
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 2.1002
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5000 - loss: 2.0867
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5000 - loss: 2.0731
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5294 - loss: 2.0596
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5294 - loss: 2.0461
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5588 - loss: 2.0326
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5588 - loss: 2.0192
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5588 - loss: 2.0058
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5588 - loss: 1.9924
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5588 - loss: 1.9791
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5588 - loss: 1.9657
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5588 - loss: 1.9525
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5588 - loss: 1.9392
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5588 - loss: 1.9260
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5588 - loss: 1.9129
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5588 - loss: 1.8998
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5588 - loss: 1.8867
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5588 - loss: 1.8737
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5588 - loss: 1.8607
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5588 - loss: 1.8478
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5588 - loss: 1.8350
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5588 - loss: 1.8222
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5588 - loss: 1.8094
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5588 - loss: 1.7967
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5882 - loss: 1.7841
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5882 - loss: 1.7716
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5882 - loss: 1.7591
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5882 - loss: 1.7466
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5882 - loss: 1.7342
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5882 - loss: 1.7219
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5882 - loss: 1.7097
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5882 - loss: 1.6975
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5882 - loss: 1.6854
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5882 - loss: 1.6733
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5882 - loss: 1.6614
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6471 - loss: 1.6494
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6471 - loss: 1.6376
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6765 - loss: 1.6258
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6765 - loss: 1.6141
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7059 - loss: 1.6025
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7353 - loss: 1.5909
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7353 - loss: 1.5794
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7353 - loss: 1.5680
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7353 - loss: 1.5567
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7353 - loss: 1.5454
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7353 - loss: 1.5342
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7353 - loss: 1.5231
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7353 - loss: 1.5120
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7353 - loss: 1.5010
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7353 - loss: 1.4901
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7353 - loss: 1.4793
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7353 - loss: 1.4685
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7353 - loss: 1.4578
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7353 - loss: 1.4472
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7647 - loss: 1.4366
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7647 - loss: 1.4262
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7647 - loss: 1.4158
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7647 - loss: 1.4054
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7647 - loss: 1.3952
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7647 - loss: 1.3850
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7647 - loss: 1.3749
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7647 - loss: 1.3648
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7647 - loss: 1.3549

# %%
# Step 7: Save word vectors

weights = model.get_layer("embedding").get_weights()[0]

items = sorted([(w, idx) for w, idx in word_index.items() if idx < weights.shape[0] and idx != 0], key=lambda t: t[1])
num_vectors = len(items)

with open("vectors.txt", "w", encoding="utf-8") as f:
    f.write(f"{num_vectors} {embed_dim}\n")
    for word, idx in items:
        vec = " ".join(map(str, weights[idx].tolist()))
        f.write(f"{word} {vec}\n")

print("vectors.txt saved successfully!")
# Out:
# vectors.txt saved successfully!

# %%
# Step 8: Test with Gensim

cbow_vectors = KeyedVectors.load_word2vec_format("vectors.txt", binary=False)
print("Words in vocab:", cbow_vectors.index_to_key)

for w in ["day", "park", "children", "learning"]:
    if w in cbow_vectors:
        print(f"\nMost similar to '{w}':")
        print(cbow_vectors.most_similar(positive=[w], topn=5))
# Out:
# Words in vocab: ['<OOV>', 'the', 'is', 'day', 'are', 'it', 'a', 'pleasant', 'i', 'love', 'to', 'walk', 'in', 'park', 'birds', 'singing', 'and', 'breeze', 'cool', 'children', 'playing', 'games', 'with', 'joy', 'learning', 'new', 'things', 'every', 'feels', 'rewarding']
#
# Most similar to 'day':
# [('new', 0.9500630497932434), ('feels', 0.9401335120201111), ('things', 0.9053399562835693), ('i', 0.10151601582765579), ('is', 0.03644341230392456)]
#
# Most similar to 'park':
# [('walk', 0.6768845915794373), ('to', 0.47550222277641296), ('in', 0.3671855628490448), ('birds', 0.3251141607761383), ('and', 0.2331017553806305)]
#
# Most similar to 'children':
# [('games', 0.7554316520690918), ('with', 0.6062850952148438), ('and', 0.42861440777778625), ('birds', 0.4261351525783539), ('playing', 0.4172697961330414)]
#
# Most similar to 'learning':
# [('every', 0.7242977619171143), ('<OOV>', 0.392718106508255), ('joy', 0.2767900228500366), ('with', 0.2349032461643219), ('playing', 0.21702761948108673)]
